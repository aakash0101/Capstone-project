# %% [markdown]
# # ---------------------------------Crime in India-------------------------------------

# %% [markdown]
# # ------------------------Capstone Project Phase 1--------------------------

# %% [markdown]
# # BY: Aakash bindal.

# %% [markdown]
# # Batch Number:DS2401.

# %% [markdown]
# # Data Collection/preparation part.
#
#
#
# Note:
#
# You can collect data from anywhere (wiki, google, etc) but mention the link from where data is being collected.
#
# You can collect the data manually. It's NOT a web scraping task.
#
# Data should be collected for the years mentioned in the files. (If you don't find proper data, make your best judgment and fill it, It's absolutely OK. Do not worry about data accuracy.)
#
#
# Data
#
# 1) The population of each state.
#
# 2) Literacy Rate in each state
#
# 3) Area of each state
#
# 4) Collect any other data that helps with your analysis. There is no limitation for anything.
#
# Create a new file and keep the above-collected data.

# %% [markdown]
# # Data collection links
# ### Link -
# https://en.wikipedia.org/wiki/Crime_in_India#:~:text=The%20violent%20crime%20rate%20(per,and%20Arunachal%20Pradesh%20(41.7).
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_crime_rate
#
# ## Literacy rate in india census 2021 and NSO survey
# https://en.wikipedia.org/wiki/List_of_Indian_states_and_union_territories_by_literacy_rate
#
# ## Area of Indian territory link
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area
#
# ## population in india
# https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r"/Users/aakashbindal/Documents/Capstone-phase1.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0          State&Uts Population_2021  Population_1951  \
# 0           1      A & N Islands          417036          31480.0
# 1           2     Andhra Pradesh     5,39,03,393       31115000.0
# 2           3  Arunachal Pradesh       15,70,458              NaN
# 3           4              Assam     3,56,07,039        8029100.0
# 4           5              Bihar    12,47,99,926       29085900.0
#
#    Population_1961  Population_1971  Population_1981  Population_1991  \
# 0          64160.0         115874.0         189496.0         281990.0
# 1       35983480.0       43502710.0       53551030.0       66508170.0
# 2         337300.0         468885.0         632502.0         865900.0
# 3       10837700.0       14625157.0       18041250.0       22414320.0
# 4       34841490.0       42126800.0       52303000.0       64531200.0
#
#    Population_2001  Population_2011  ...  Robbery Hit_&_Run  \
# 0         356650.0           379944  ...      0.5       0.7
# ...

# %%
print('Number of Rows :',df.shape[0])
print('Number of Columns :',df.shape[1])
# Out:
# Number of Rows : 36
# Number of Columns : 41

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State&Uts', 'Population_2021', 'Population_1951',
#        'Population_1961', 'Population_1971', 'Population_1981',
#        'Population_1991', 'Population_2001', 'Population_2011', 'Area (km2)',
#        'Region', 'Area_Percentage', 'Literacy_rate_1951', 'Literacy_rate_1961',
#        'Literacy_rate_1971', 'Literacy_rate_1981', 'Literacy_rate_1991',
#        'Literacy_rate_2001', 'Literacy_rate_2011', 'Crime_rate_2018',
#        'Crime_rate_2019', 'Crime_rate_2020', 'Crime_rate_2021',
#        'crime_density_2021', 'Violent_Crimes', 'Murder', 'Rape', 'Kidnapping',
#        'Crimes_Against_Children', 'Extortion', 'Robbery', 'Hit_&_Run',
#        'Drugs_Trafficking', 'Illegal_Arms', 'Avg_literacy_rate_2011',
#        'Male_literacy_rate', 'Female_literacy_rate',
#        'Average_NSO_literacy_rate_2017', 'Male_literacy_rate_2017',
#        'Female_literacy_rate_2017'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      36 non-null     int64
#  1   State&Uts                       36 non-null     object
#  2   Population_2021                 36 non-null     object
#  3   Population_1951                 34 non-null     float64
#  4   Population_1961                 35 non-null     float64
#  5   Population_1971                 35 non-null     float64
#  6   Population_1981                 35 non-null     float64
#  7   Population_1991                 35 non-null     float64
#  8   Population_2001                 35 non-null     float64
#  9   Population_2011                 36 non-null     int64
#  10  Area (km2)                      36 non-null     int64
#  11  Region                          36 non-null     object
# ...

# %% [markdown]
# # checking null values or unwanted values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# State&Uts                         0
# Population_2021                   0
# Population_1951                   2
# Population_1961                   1
# Population_1971                   1
# Population_1981                   1
# Population_1991                   1
# Population_2001                   1
# Population_2011                   0
# Area (km2)                        0
# Region                            0
# Area_Percentage                   0
# Literacy_rate_1951                2
# Literacy_rate_1961                2
# Literacy_rate_1971                2
# Literacy_rate_1981                2
# Literacy_rate_1991                2
# Literacy_rate_2001                2
# Literacy_rate_2011                2
# Crime_rate_2018                   0
# Crime_rate_2019                   0
# Crime_rate_2020                   0
# Crime_rate_2021                   0
# crime_density_2021                0
# Violent_Crimes                    0
# ...

# %% [markdown]
# Indicates that there are  null values within the dataset.

# %%
#checking unwanted values
df.isin(['-']).sum()
# Out:
# Unnamed: 0                         0
# State&Uts                          0
# Population_2021                    0
# Population_1951                    0
# Population_1961                    0
# Population_1971                    0
# Population_1981                    0
# Population_1991                    0
# Population_2001                    0
# Population_2011                    0
# Area (km2)                         0
# Region                             0
# Area_Percentage                    0
# Literacy_rate_1951                15
# Literacy_rate_1961                 6
# Literacy_rate_1971                 1
# Literacy_rate_1981                 2
# Literacy_rate_1991                 1
# Literacy_rate_2001                 0
# Literacy_rate_2011                 0
# Crime_rate_2018                    2
# Crime_rate_2019                    2
# Crime_rate_2020                    0
# Crime_rate_2021                    0
# crime_density_2021                 0
# ...

# %% [markdown]
# Indicates that there are  unwanted values within the dataset.

# %% [markdown]
# # convert unwanted values into null values and check again

# %%
df.replace('-',np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         0
# State&Uts                          0
# Population_2021                    0
# Population_1951                    2
# Population_1961                    1
# Population_1971                    1
# Population_1981                    1
# Population_1991                    1
# Population_2001                    1
# Population_2011                    0
# Area (km2)                         0
# Region                             0
# Area_Percentage                    0
# Literacy_rate_1951                17
# Literacy_rate_1961                 8
# Literacy_rate_1971                 3
# Literacy_rate_1981                 4
# Literacy_rate_1991                 3
# Literacy_rate_2001                 2
# Literacy_rate_2011                 2
# Crime_rate_2018                    2
# Crime_rate_2019                    2
# Crime_rate_2020                    0
# Crime_rate_2021                    0
# crime_density_2021                 0
# ...

# %% [markdown]
# # filling null values

# %%
df.fillna(0,inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                        0
# State&Uts                         0
# Population_2021                   0
# Population_1951                   0
# Population_1961                   0
# Population_1971                   0
# Population_1981                   0
# Population_1991                   0
# Population_2001                   0
# Population_2011                   0
# Area (km2)                        0
# Region                            0
# Area_Percentage                   0
# Literacy_rate_1951                0
# Literacy_rate_1961                0
# Literacy_rate_1971                0
# Literacy_rate_1981                0
# Literacy_rate_1991                0
# Literacy_rate_2001                0
# Literacy_rate_2011                0
# Crime_rate_2018                   0
# Crime_rate_2019                   0
# Crime_rate_2020                   0
# Crime_rate_2021                   0
# crime_density_2021                0
# Violent_Crimes                    0
# ...

# %% [markdown]
# After filling the null values, there are now no nulls present in the dataset.

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)

# %% [markdown]
# Dropping the 'Unnamed: 0' column as it is not required in the dataset.

# %% [markdown]
# # ---------------------Capstone Project Phase 2-----------------------------------

# %% [markdown]
# State/UT wise analysis.
#
# Note :
#
# You need to be careful as this phase is whole state/UT wise analysis (not district-wise).
#
# It is up to you which columns you want to keep or delete to make proper analysis"
#
#            2.1	Analysis of Literacy Rate vs Total Crimes.
#
#            2.2	Analysis of the type of crime vs each state vs Literacy rate.
#
#            2.3	Analysis of year-on-year total crime rate.
#
#            2.4	Analysis of area vs overall crime.
#
#            2.5	Analysis of Population vs overall Crime.
#
#            2.6	Each state crime report.
#
# There is no fixed format to write a report, you can write a report inside the notebook itself based on what you have analyzed in the above points.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # =========2.1-	Analysis of Literacy Rate vs Total Crimes ===========

# %% [markdown]
# ## Literacy Rate According to Census from [1951-2011]

# %%
# Selecting columns of interest
years = ['1951', '1961', '1971', '1981', '1991', '2001', '2011']
columns_to_plot = [f'Literacy_rate_{year}' for year in years]

plt.figure(figsize=(25, 10))

# Iterating through columns to plot each line
for column in columns_to_plot:
    plt.plot(df['State&Uts'], df[column], marker='o', label=column)

plt.xlabel('State & Uts', fontsize=25)
plt.ylabel('Literacy Rate Over The Years', fontsize=25)
plt.title('Literacy Rate According To Census')
plt.xticks(fontsize=15, rotation=90)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The literacy rate in India has shown remarkable improvement from the 1951 census to the 2011 census, reflecting the nation's evolving educational landscape.
#
# 1951 Census: The literacy rate in India was approximately 18.33% in 1951, highlighting widespread illiteracy and limited educational access.
#
# 1971 Census: By 1971, the literacy rate had increased to about 29.45%, attributed to government-led educational initiatives and infrastructure development.
#
# 1991 Census: In 1991, the literacy rate rose to around 52.21%, driven by expanded educational opportunities and awareness programs.
#
# 2001 Census: By 2001, the literacy rate reached approximately 64.84%, with a focus on universal primary education and gender equality in schooling.
#
# 2011 Census: In 2011, India achieved a literacy rate of about 74.04%, marking significant progress due to continued government investment and enhanced educational awareness.
#
# While these gains are notable, challenges like regional disparities and quality of education persist. The Indian government remains committed to improving literacy through targeted policies and initiatives.

# %%
plt.figure(figsize = (15,5))
plt.title(" Literacy Rate 2011", fontsize=22, fontweight='bold')
a= sns.barplot(x = "State&Uts", y = "Avg_literacy_rate_2011", data = df,palette="deep")
a.set_xlabel('State&Uts',fontsize=20)
a.set_ylabel('Literacy Rate',fontsize=18)
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.title("Literacy Rate 2011 vs Crime Density", fontsize=22, fontweight='bold')

# Create the bar plot
sns.barplot(x="State&Uts", y="crime_density_2021", data=df, palette="deep")
plt.xlabel('State & Uts', fontsize=20)
plt.ylabel('Crime Density', fontsize=18)
plt.xticks(fontsize=12, rotation=90)

# Overlay a line plot of another column (literacy rate)
plt.plot(df['State&Uts'], df['Avg_literacy_rate_2011'], marker='o', color='red', label='Literacy Rate')

# Adjusting legend, labels, and grid
plt.legend(fontsize=14)
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ## NSO Survey Literacy Rate of 2017
#
#
# NSO regularly conducts surveys on various aspects of the Indian population, including education, employment, and health, specific surveys focused solely on literacy rates may not be conducted as frequently as the decennial census.

# %%
plt.figure(figsize = (12,5))
plt.title(" NSO Survey Literacy Rate of 2017", fontsize=22, fontweight='bold')
a= sns.barplot(x = "State&Uts", y = "Average_NSO_literacy_rate_2017", data = df)
a.set_xlabel('State&Uts',fontsize=20)
a.set_ylabel('Literacy Rate',fontsize=18)
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %% [markdown]
# ## Male  & Female Literacy Rate in 2017

# %%
plt.figure(figsize = (16,6))
plt.plot(df['State&Uts'], df['Male_literacy_rate_2017'], marker='o', label='Male_literacy_rate_2017')
plt.plot(df['State&Uts'], df['Female_literacy_rate_2017'], marker='o', label='Female_literacy_rate_2017')
plt.xlabel('State&Uts',fontsize = 25)
plt.ylabel('Literacy Rate ',fontsize = 25)
plt.title('Male/Female Literacy Rate 2017')
plt.xticks(fontsize=18,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# This data pertains to the NSO survey of 2017.
# In Delhi, female literacy rates surpass male literacy rates.
# Kerala boasts the highest literacy rate among all states, with nearly equal literacy rates for both genders.
# Conversely, Bihar, Rajasthan, Uttar Pradesh, and Arunachal Pradesh exhibit the lowest literacy rates.
# Data for Ladakh is unavailable as this Union Territory was established in 2019.

# %% [markdown]
# # == 2.2 Analysis of the type of crime vs each state vs Literacy rate ====

# %% [markdown]
# # Types of Crime In INDIA

# %%
plt.figure(figsize=(26, 10))
plt.title('Types of Crimes and Average NSO Literacy Rate (2017)', fontsize=25)

# Define crime columns to plot
crime_columns = ['Violent_Crimes', 'Murder', 'Rape', 'Kidnapping', 
                 'Crimes_Against_Children', 'Extortion', 'Robbery', 
                 'Hit_&_Run', 'Drugs_Trafficking', 'Illegal_Arms']

# Plotting crimes
for crime in crime_columns:
    plt.plot(df['State&Uts'], df[crime], marker='o', label=crime)

# Plotting average NSO literacy rate
plt.plot(df['State&Uts'], df['Average_NSO_literacy_rate_2017'], 
         marker='o', label='Average NSO Literacy Rate (2017)', linewidth=5)

plt.xlabel('State & Uts', fontsize=25)
plt.ylabel('Number of Crimes', fontsize=25)
plt.xticks(fontsize=18, rotation=90)
plt.legend(fontsize='large')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comment -
# -Crime Against Children is notably high across several states, including Andaman & Nicobar, Delhi, Sikkim, Haryana, Chandigarh, Madhya Pradesh, Chhattisgarh, Maharashtra, and Lakshadweep, consistently above average compared to other states.
#
# -Cases involving illegal arms are particularly prevalent in Uttar Pradesh and Uttarakhand.
#
# -Violent crime rates are prominently high across all states, with Assam, Delhi, Odisha, and Haryana showing notably elevated rates.
#
# -Delhi exhibits the highest incidence of kidnapping among all states.

# %% [markdown]
# ## Crime Density in 2021 vs Average Literacy Rate

# %%
plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['crime_density_2021'], marker='o', label='crime_density_2021')
plt.plot(df['State&Uts'], df['Average_NSO_literacy_rate_2017'], marker='o', label='Average_NSO_literacy_rate_2017',linewidth=2)
plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime_density ',fontsize = 16)
plt.title('crime_density_2021')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Comment -
# * Crime Density is Highest in Delhi.
# * Top 5 State&UTs is [Delhi, kerala, Tamil Nadu, Puducherry, chandigarh ] in Crime Rate Density.

# %% [markdown]
# # ----------------2.3 Analysis of year-on-year total crime rate----------------

# %% [markdown]
# ## Crime Rate Of Year [2018,2019,2020,2021] Vs Literacy Rate

# %%
plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['Crime_rate_2018'], marker='o', label='Crime_rate_2018')
plt.plot(df['State&Uts'], df['Crime_rate_2019'], marker='o', label='Crime_rate_2019')
plt.plot(df['State&Uts'], df['Crime_rate_2020'], marker='o', label='Crime_rate_2020')
plt.plot(df['State&Uts'], df['Crime_rate_2021'], marker='o', label='Crime_rate_2021')


plt.plot(df['State&Uts'], df['Average_NSO_literacy_rate_2017'], marker='o', label='Average_NSO_literacy_rate_2017',linewidth=5)

plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime Rate ',fontsize = 16)
plt.title('crime_Rate Over The Years Vs Average Literacy Rate 2017')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## comment - This  Crime report of INDIA is given by NCRB's.
# 2018: According to the NCRB's "Crime in India" report for 2018, there was an increase in reported crimes nationwide compared to the previous year. Categories like murder, kidnapping, robbery, and cybercrime exhibited varying trends across states and union territories.
#
# 2019: The NCRB's 2019 report continued to show an overall rise in reported crimes, with specific crime categories potentially showing fluctuating rates year over year.
#
# 2020: The COVID-19 pandemic significantly impacted various aspects of society, including crime rates. Lockdowns and restrictions during the pandemic may have influenced crime patterns, particularly in areas like theft, domestic violence, and cybercrime. However, detailed official data for 2020 is required to fully understand these changes.
#
# 2021: Data for 2021 may still be under collection and analysis, making it challenging to fully assess crime trends. However, it's plausible that pandemic-related influences continued to shape crime rates, with potential shifts in patterns as circumstances evolved.

# %% [markdown]
# While literacy rates may impact crime rates, it's essential to acknowledge the intricate interaction of multiple factors—social, economic, cultural, and institutional—that shape crime dynamics. Factors like poverty, inequality, unemployment, access to justice, law enforcement effectiveness, social cohesion, and cultural norms also play pivotal roles in influencing crime rates.

# %% [markdown]
# # ---------------2.4 Analysis of area vs overall crime------------------

# %%
plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['crime_density_2021'], marker='o', label='crime_density_2021')
plt.plot(df['State&Uts'], df['Area (km2)'], marker='o', label='Area',linewidth=3)

plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime Rate ',fontsize = 16)
plt.title('crime_Rate Over The Years Vs Area')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Comment -
# * Area are not related to Crime anymore.
# * But in Delhi Area is very Less Instead Crime rate is very high. Because Population Density is Also factor.

# %% [markdown]
# # ---------------2.5 Analysis of Population vs overall Crime--------------------

# %%
df['Population_2021'] = df['Population_2021'].str.replace(',', '').astype(float)

plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['crime_density_2021'], marker='o', label='crime_density_2021')
plt.plot(df['State&Uts'], df['Population_2021'], marker='o', label='Population',linewidth=3)

plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime Rate ',fontsize = 16)
plt.title('crime_Rate  Vs Population')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # -------------------2.6	Each state crime report------------------------

# %% [markdown]
# State Crime Rates: In 2021, Uttar Pradesh recorded the highest crime rate among Indian states, while Nagaland reported the lowest. Delhi had the highest overall crime rate, with D&N Haveli and Daman & Diu recording the lowest.
#
# Violent Crimes: Eastern and Northeastern India, along with the National Capital Region, showed notably high rates of violent crimes. States like Bihar, Jharkhand, Odisha, West Bengal, Assam, Tripura, Arunachal Pradesh, Delhi, Haryana, Maharashtra, and Madhya Pradesh had violent crime rates above the national average in 2021.
#
# Murder Rate: Jharkhand reported the highest murder rate in 2021.
#
# Rape Rates: Chandigarh had the highest rape rates among Indian states in 2021, while Rajasthan reported the highest number of rape cases.
#
# Kidnapping and Robbery: Delhi recorded the highest rates of kidnapping and robbery in 2021.
#
# Drugs Trafficking: Punjab reported the highest government-sponsored drugs trafficking rate in 2021.
#
# Illegal Arms Seizure: Uttar Pradesh reported the highest rate of illegal arms seizure in 2021.
#
# Specific Causes of Crimes: Region-specific factors contributed significantly to crime rates. For instance, insurgents committed 178 crimes in 2021, primarily in Manipur. Left-wing extremists were responsible for 387 crimes, mainly in Chhattisgarh, while terrorists committed 380 crimes, predominantly in Jammu & Kashmir.
#
# Investigation and Charge-Sheeting Rates: Gujarat had the highest investigation and charge-sheeting rates in 2021, whereas Manipur had the lowest.
#
# Conviction Rates: Mizoram reported the highest conviction rate, while Lakshadweep had the lowest in 2021.
